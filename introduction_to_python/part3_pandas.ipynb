# %% [markdown]
# # A quick introduction to Pandas
#
# Pandas is a very popular tool for dealing with tabular data. You can read a csv, excell, or access a database directly.
#
# You can group by, you can make plots, fill missing values. There is a lot that you can do.
#
#
# ## Pandas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import sys

# %%
# lets load the titanic survival data
# df_titanic = sns.load_dataset('titanic')
# df_titanic.to_csv("titanic_dataset.csv",index=False)

# %%
df_titanic = pd.read_csv("titanic_dataset.csv")

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
type(df_titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
df_titanic.shape
# Out:
# (891, 15)

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # column, index, values
#
# The dataframe has three main parts. the index, column, and values. You will see the values is simply a numpy matrix. Behind the scenes pandas uses numpy very heavily. This is good to know, because it means any operation you would like to do in numpy, you can also do in pandas

# %%
df_titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df_titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df_titanic.values
# Out:
# array([[0, 3, 'male', ..., 'Southampton', 'no', False],
#        [1, 1, 'female', ..., 'Cherbourg', 'yes', False],
#        [1, 3, 'female', ..., 'Southampton', 'yes', True],
#        ...,
#        [0, 3, 'female', ..., 'Southampton', 'no', False],
#        [1, 1, 'male', ..., 'Cherbourg', 'yes', True],
#        [0, 3, 'male', ..., 'Queenstown', 'no', True]], dtype=object)

# %%
type(df_titanic.values)
# Out:
# numpy.ndarray

# %% [markdown]
# # Picking columns

# %%
# picking a single column
df_titanic["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
# picking few columns
df_titanic[["age","sex"]]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# 5     NaN    male
# 6    54.0    male
# 7     2.0    male
# 8    27.0  female
# 9    14.0  female
# 10    4.0  female
# 11   58.0  female
# 12   20.0    male
# 13   39.0    male
# 14   14.0  female
# 15   55.0  female
# 16    2.0    male
# 17    NaN    male
# 18   31.0  female
# 19    NaN  female
# 20   35.0    male
# 21   34.0    male
# 22   15.0  female
# 23   28.0    male
# 24    8.0  female
# 25   38.0  female
# 26    NaN    male
# 27   19.0    male
# 28    NaN  female
# 29    NaN    male
# ..    ...     ...
# 861  21.0    male
# 862  48.0  female
# 863   NaN  female
# 864  24.0    male
# 865  42.0  female
# 866  27.0  female
# 867  31.0    male
# 868   NaN    male
# 869   4.0    male
# 870  26.0    male
# 871  47.0  female
# 872  33.0    male
# 873  47.0    male
# 874  28.0  female
# 875  15.0  female
# 876  20.0    male
# 877  19.0    male
# 878   NaN    male
# ...

# %% [markdown]
# # Pandas Series
# notice that when we picked only one column, the output looked a bit different, because when you only pick one column in pandas, that is a different object type. It is a pandas series.
#
# Most of the time, you dont need to worry about this, but some operations work differently on series than they do to dataframes.

# %%
type(df_titanic["age"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Series to Dataframe
#
# If I want to convert a series into a dataframe, one way to do it is to call reset_index()

# %%
my_series = df_titanic["age"]
my_series.reset_index()
# Out:
#      index   age
# 0        0  22.0
# 1        1  38.0
# 2        2  26.0
# 3        3  35.0
# 4        4  35.0
# 5        5   NaN
# 6        6  54.0
# 7        7   2.0
# 8        8  27.0
# 9        9  14.0
# 10      10   4.0
# 11      11  58.0
# 12      12  20.0
# 13      13  39.0
# 14      14  14.0
# 15      15  55.0
# 16      16   2.0
# 17      17   NaN
# 18      18  31.0
# 19      19   NaN
# 20      20  35.0
# 21      21  34.0
# 22      22  15.0
# 23      23  28.0
# 24      24   8.0
# 25      25  38.0
# 26      26   NaN
# 27      27  19.0
# 28      28   NaN
# 29      29   NaN
# ..     ...   ...
# 861    861  21.0
# 862    862  48.0
# 863    863   NaN
# 864    864  24.0
# 865    865  42.0
# 866    866  27.0
# 867    867  31.0
# 868    868   NaN
# 869    869   4.0
# 870    870  26.0
# 871    871  47.0
# 872    872  33.0
# 873    873  47.0
# 874    874  28.0
# 875    875  15.0
# 876    876  20.0
# 877    877  19.0
# 878    878   NaN
# 879    879  56.0
# 880    880  25.0
# ...

# %% [markdown]
# Alternatively, you can create a one column dataframe from the start

# %%
df_titanic[["age"]]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# 10    4.0
# 11   58.0
# 12   20.0
# 13   39.0
# 14   14.0
# 15   55.0
# 16    2.0
# 17    NaN
# 18   31.0
# 19    NaN
# 20   35.0
# 21   34.0
# 22   15.0
# 23   28.0
# 24    8.0
# 25   38.0
# 26    NaN
# 27   19.0
# 28    NaN
# 29    NaN
# ..    ...
# 861  21.0
# 862  48.0
# 863   NaN
# 864  24.0
# 865  42.0
# 866  27.0
# 867  31.0
# 868   NaN
# 869   4.0
# 870  26.0
# 871  47.0
# 872  33.0
# 873  47.0
# 874  28.0
# 875  15.0
# 876  20.0
# 877  19.0
# 878   NaN
# 879  56.0
# 880  25.0
# 881  33.0
# 882  22.0
# 883  28.0
# 884  25.0
# 885  39.0
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %% [markdown]
# # Filtering
#
# Lets say I wanted to filter the data for only people who embarked at southampton

# %%
df_titanic[df_titanic["embark_town"]=="Southampton"].head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 6    man        True    E  Southampton    no   True

# %% [markdown]
# So whats happening here? This is the kind of indexing that you may have seen for numpy arrays. It is referred to as boolean indexing. You can see below that `df_titanic["embark_town"]=="Southampton"` returns an array of `True` and `False` statements.

# %%
df_titanic["embark_town"]=="Southampton"
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
# 6       True
# 7       True
# 8       True
# 9      False
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16     False
# 17      True
# 18      True
# 19     False
# 20      True
# 21      True
# 22     False
# 23      True
# 24      True
# 25      True
# 26     False
# 27      True
# 28     False
# 29      True
#        ...
# 861     True
# 862     True
# 863     True
# 864     True
# 865     True
# 866    False
# 867     True
# 868     True
# 869     True
# 870     True
# 871     True
# 872     True
# 873     True
# 874    False
# 875    False
# 876     True
# 877     True
# 878     True
# 879    False
# 880     True
# 881     True
# 882     True
# 883     True
# 884     True
# 885    False
# 886     True
# 887     True
# 888     True
# 889    False
# 890    False
# Name: embark_town, Length: 891, dtype: bool

# %% [markdown]
# # group by

# %%
# we are grouping by "sex", and we are taking the mean of the "survived" paramater
df_grouped_by_sex = df_titanic.groupby("sex")["survived"].mean()
df_grouped_by_sex
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df_grouped_by_sex = df_grouped_by_sex * 100 # so its a percentage

# %%
df_grouped_by_sex.plot.bar()
plt.ylabel("Survival Rate (%)")
# Out:
# Text(0, 0.5, 'Survival Rate (%)')
